# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from time import time
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from gensim.models.phrases import Phrases, Phraser
import string

# %%
# Function to reduce the memory usage of a DataFrame.
def reduce_memory(df):
    for col in df.columns:
        if df[col].dtype == 'float64':
            df[col] = df[col].astype('float32')
        if df[col].dtype == 'int64':
            df[col] = df[col].astype('int32')
    return df

# Generator function to load data in chunks.
def data_generator(df, chunksize=10000):
    for i in range(0, df.shape[0], chunksize):
        yield df.iloc[i:i+chunksize]

# %%
df = reduce_memory(pd.read_csv("data/Dataset.csv"))

# %%
df.head()
# Out:
#    UserID                        Game purchase/play  Heure_jouee  AppID  \
# 0       1  The Elder Scrolls V Skyrim          play        273.0  72850
# 1       2  The Elder Scrolls V Skyrim          play         58.0  72850
# 2       3  The Elder Scrolls V Skyrim          play        110.0  72850
# 3       4  The Elder Scrolls V Skyrim          play        465.0  72850
# 4       5  The Elder Scrolls V Skyrim          play        220.0  72850
#
#    Release date    Estimated owners  Peak CCU  Required age  Price  ...  \
# 0  Nov 10, 2011  5000000 - 10000000      4383            17  19.99  ...
# 1  Nov 10, 2011  5000000 - 10000000      4383            17  19.99  ...
# 2  Nov 10, 2011  5000000 - 10000000      4383            17  19.99  ...
# 3  Nov 10, 2011  5000000 - 10000000      4383            17  19.99  ...
# 4  Nov 10, 2011  5000000 - 10000000      4383            17  19.99  ...
#
#    Median playtime forever Median playtime two weeks             Developers  \
# 0                50.533333                 14.633333  Bethesda Game Studios
# 1                50.533333                 14.633333  Bethesda Game Studios
# 2                50.533333                 14.633333  Bethesda Game Studios
# 3                50.533333                 14.633333  Bethesda Game Studios
# 4                50.533333                 14.633333  Bethesda Game Studios
#
#            Publishers                                         Categories  \
# 0  Bethesda Softworks  Single-player,Steam Achievements,Steam Trading...
# 1  Bethesda Softworks  Single-player,Steam Achievements,Steam Trading...
# 2  Bethesda Softworks  Single-player,Steam Achievements,Steam Trading...
# 3  Bethesda Softworks  Single-player,Steam Achievements,Steam Trading...
# 4  Bethesda Softworks  Single-player,Steam Achievements,Steam Trading...
#
#    Genres                                               Tags  Score  \
# 0     RPG  Open World,RPG,Fantasy,Adventure,Dragons,Modda...    5.0
# 1     RPG  Open World,RPG,Fantasy,Adventure,Dragons,Modda...    5.0
# 2     RPG  Open World,RPG,Fantasy,Adventure,Dragons,Modda...    5.0
# 3     RPG  Open World,RPG,Fantasy,Adventure,Dragons,Modda...    5.0
# 4     RPG  Open World,RPG,Fantasy,Adventure,Dragons,Modda...    5.0
#
#    Recommandable  GameID
# 0           True       1
# 1           True       1
# 2           True       1
# 3           True       1
# 4           True       1
#
# [5 rows x 38 columns]

# %%
# from scipy.sparse import coo_matrix

# # map each user and item to a unique numeric value
# user_ids = df['UserID'].astype('category').cat.codes
# item_ids = df['GameID'].astype('category').cat.codes

# # Get the unique user and game ids
# unique_user_ids = df['UserID'].astype('category').cat.categories
# unique_item_ids = df['GameID'].astype('category').cat.categories

# # create a sparse matrix
# user_game_matrix = coo_matrix((df['Heure_jouee'], (user_ids, item_ids)))

# # Fit the model
# model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
# model_knn.fit(user_game_matrix)

# # Get top 5 recommendations for first user
# distances, indices = model_knn.kneighbors(user_game_matrix.getrow(0), n_neighbors=6)
# recommended_users = [unique_user_ids[i] for i in indices.flatten()[1:]]
# print(f'Recommended users for the first user are: {recommended_users}')

# %%
from scipy.sparse import coo_matrix
from sklearn.neighbors import NearestNeighbors

# map each user and item to a unique numeric value
user_ids = df['UserID'].astype('category').cat.codes
item_ids = df['GameID'].astype('category').cat.codes

# Get the unique user and game ids
unique_user_ids = df['UserID'].astype('category').cat.categories
unique_item_ids = df['GameID'].astype('category').cat.categories

# create a sparse matrix
user_game_matrix = coo_matrix((df['Heure_jouee'], (user_ids, item_ids)))

# Fit the model
model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
model_knn.fit(user_game_matrix)

# Get top 5 recommendations for first user
distances, indices = model_knn.kneighbors(user_game_matrix.getrow(0), n_neighbors=6)

# Get the games played by the first user
games_played_by_user = df[df['UserID'] == unique_user_ids[0]]['GameID'].values

# Get the recommended users excluding the first user
recommended_users = [unique_user_ids[i] for i in indices.flatten()[1:]]

# Find games played by the recommended users but not played by the first user
games_played_by_recommended_users = df[df['UserID'].isin(recommended_users)]['GameID'].values
recommended_games = set(games_played_by_recommended_users) - set(games_played_by_user)

# Sort recommended games by total playtime in descending order
sorted_recommended_games = sorted(recommended_games, key=lambda game_id: df[df['GameID'] == game_id]['Heure_jouee'].sum(), reverse=True)

# Print the top 5 games recommended for the first user based on total playtime of recommended users
print(f'Top 5 games recommended for the first user based on total playtime of recommended users:')
for game_id in sorted_recommended_games[:5]:
    game_name = df[df['GameID'] == game_id]['Game'].values[0]
    print(game_name)
# Out:
# Top 5 games recommended for the first user based on total playtime of recommended users:
# Counter-Strike Global Offensive
# Warframe
# Borderlands 2
# Portal 2
# ARK Survival Evolved

# %%
## On analyse le UserID n°1

# df[df["UserID"] == 1]

## L'algo nous indique que les UserID les plus proches sont les 5 suivants

# df[df["UserID"] == 332]
# df[df["UserID"] == 338]
# df[df["UserID"] == 598]
# df[df["UserID"] == 370]
df[df["UserID"] == 140]
